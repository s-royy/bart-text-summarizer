# %% [markdown]
# <h1><b>Install & Import</b></h1>

# %%
# !pip install transformers torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# %% [markdown]
# <h1><b>Load Model</b></h1>

# %%
model_name = "facebook/bart-large-cnn"
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# <h1><b>Summarize Function</b></h1>

# %%
def summarize(text):
    tokens = tokenizer.encode(text, truncation=False)
    chunks = [tokens[i:i+1024] for i in range(0, len(tokens), 1024)]

    summaries = []
    for chunk in chunks:
        chunk_text = tokenizer.decode(chunk, skip_special_tokens=True)
        inputs = tokenizer(chunk_text, max_length=1024, truncation=True, return_tensors="pt")
        summary_ids = model.generate(inputs["input_ids"], max_length=150, min_length=50, num_beams=4)
        summaries.append(tokenizer.decode(summary_ids[0], skip_special_tokens=True))

    return " ".join(summaries)

# %% [markdown]
# <h1><b>Interactive Summarization</b></h1>

# %%
text = input("Enter text to summarize:\n")
summary = summarize(text)
print("\nSummary:\n" + summary)
# Out:
# Enter text to summarize:
# Artificial intelligence has transformed numerous industries over the past decade, revolutionizing how businesses operate and how people interact with technology. From healthcare diagnostics to autonomous vehicles, machine learning models now perform tasks that once seemed impossible for computers to handle. Natural language processing, in particular, has seen remarkable advances with the development of transformer architectures. These models can understand context, generate coherent text, and even engage in complex reasoning tasks. However, this rapid progress has also raised important questions about ethics, bias, and the societal impact of AI systems. Researchers and policymakers continue to grapple with issues such as data privacy, algorithmic fairness, and the potential displacement of human workers. Despite these challenges, the field continues to advance at a rapid pace, with new breakthroughs announced almost weekly. Companies across sectors are investing heavily in AI research and deployment, betting that these technologies will provide competitive advantages. As AI systems become more capable and widespread, the conversation around responsible development and deployment becomes increasingly critical for ensuring these tools benefit society as a whole.
#
# Summary:
# Artificial intelligence has transformed numerous industries over the past decade. It has also raised important questions about ethics, bias, and the societal impact of AI systems. Despite these challenges, the field continues to advance at a rapid pace, with new breakthroughs announced almost weekly.
